# %% [markdown]
# <a href="https://colab.research.google.com/github/mns0/Relix/blob/main/DataModeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import os
import glob
import re
import pickle
#from hmmlearn import hmm
from pomegranate import *

# %%
pickle_file_name_open = "minimally_processed_trajectories.pkl"
with open(pickle_file_name_open, 'rb') as f:
    data = pickle.load(f)

# %%
#Determine the features 
#Click State Features 
click_event_states = set()
write_event_states = set()
for traj in data:
    flag = False
    for event in traj:
        #filter out CANT FIND MATCH and NoMatch keywords ()
        if  len(event) > 0 and event[0] == 'write':
            write_event_states.add(event[1])
        elif 0 < len(event) < 3 and event[0] == 'click' and\
            "CityNameWithZipCode" not in event[1] and not event[1][1:4].isdigit():
            click_event_states.add(event[1])
        elif 0 < len(event) < 3 and event[0] == 'click' and\
            "CityNameWithZipCode" not in event[1] and event[1][1:4].isdigit():
            click_event_states.add("Address")
        elif 0 < len(event) < 3 and event[0] == 'click' and\
            "CityNameWithZipCode":
            #for CityNameWithZipCode click events
            click_event_states.add("CityNameWithZipCode")
        else:
            pass


feature_vector = ['goto'] + list(click_event_states) + list(write_event_states)
feature_vector_to_idx = {feature : i for i, feature in enumerate(feature_vector)}
idx_to_feature_vector = {v: k for k, v in feature_vector_to_idx.items()}

# %%
#create the transition matrix
#for markov models
num_features = len(feature_vector)
outdegree = np.zeros(num_features)
transition_matrix = np.zeros((num_features,num_features))
initial_transition_vector = np.zeros(num_features)

def get_idx(line):
    ret_idx = -1
    if line[0] == 'goto':
        ret_idx = feature_vector_to_idx[line[0]]
    elif line[0] == 'write':
        ret_idx = feature_vector_to_idx[line[1]]
    elif line[0] == 'click':
        if "CityNameWithZipCode" not in line[1] and not line[1][1:4].isdigit():
            ret_idx = feature_vector_to_idx[line[1]]
        elif  "CityNameWithZipCode" in line[1]:
            ret_idx = feature_vector_to_idx["CityNameWithZipCode"]
        elif line[1][1:4].isdigit():
            ret_idx = feature_vector_to_idx["Address"]
    return ret_idx
            

for traj in data:
    for i in range(1,len(traj)):
        parent = get_idx(traj[i-1]) #row
        child = get_idx(traj[i])    #col 
        transition_matrix[parent][child] += 1
        outdegree[parent] += 1
        
        
#normalize the transition matrix
for row_idx in range(transition_matrix.shape[0]):
    a = transition_matrix[row_idx]
    b = outdegree[row_idx]
    transition_matrix[row_idx] = np.divide(a, b, out=np.zeros_like(a), where=b!=0)

# %%
#####creating dataset for hhm
sequences = []
sequences_raw = []

sequences_len = []
for traj in data:
    L = len(traj)
    traj_sequence = []
    for i in range(len(traj)):
        state = get_idx(traj[i])
        traj_sequence.append(state)
    sequences.append(traj_sequence)
    sequences_len.append(L)
    
X = np.concatenate(sequences)
#model = hmm.GaussianHMM(n_components=32).fit(X, sequences_len)

# %%
#simple MC model 
#Generate 100 samples and rank according to likilihood

mc_model = MarkovChain.from_samples(sequences)

num_of_samples = 100
seen = set()
ranked_generated_sequences = []
i=0
while i < num_of_samples:
    sample = mc_model.sample(mc_model.distributions[1])
    tup_sam = tuple(sample)
    if tup_sam not in seen:
        seen.add(tup_sam)
        log_prob = mc_model.log_probability(sample)
        #sample = [idx_to_feature_vector(i) for i in sample]
        sample = [idx_to_feature_vector[i] for i in sample]
        ranked_generated_sequences.append([np.exp(log_prob),sample])
        i+=1

    
ranked_generated_sequences.sort(reverse=True, key=lambda x : x[0],)
ranked_generated_sequences[0:100]
# Out:
# [[0.6105805335941531,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')"]],
#  [0.21596141197105895, ['goto', "'Our Services'", "'About Us'"]],
#  [0.1734580544347879,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('Or refinancing a home?')"]],
#  [0.0014746076034176311,
#   ['goto',
#    "'Our Services'",
#    "'About Us'",
#    "'View Rates'",
#    "'Refinance'",
#    "'Custom'",
#    "near('Max Rate')",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'About Us'",
#    "'View Rates'",
#    "'Refinance'",
#    "'Custom'",
#    "near('Max Rate')",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'"]],
#  [0.00069950691117,
#   ['goto',
#    "'Our Services'",
#    "'About Us'",
#    "'View Rates'",
#    "'Refinance'",
#    "'Custom'",
#    "near('Max Rate')",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'Refinance'",
#    "'Custom'",
#    "near('Max Rate')",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')"]],
#  [0.00025511591307482147,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Get a Pre-approval Letter')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'Our Services'",
#    "'About Us'",
#    "'View Rates'",
#    "'Refinance'",
#    "'Custom'",
#    "near('Max Rate')",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'"]],
#  [0.00019464399293856764,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m making offers')",
#    "near('Get a Pre-approval Letter')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'Our Services'",
#    "'About Us'",
#    "'View Rates'",
#    "'Refinance'",
#    "'Custom'",
#    "near('Max Rate')",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'"]],
#  [0.00018064760782756303,
#   ['goto',
#    "'Our Services'",
#    "'About Us'",
#    "'View Rates'",
#    "'Refinance'",
#    "'Custom'",
#    "near('Max Rate')",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('I\\'m just researching')",
#    "near('Get a Pre-approval Letter')",
#    "near('0–3 months')",
#    'citystatezip']],
#  [0.00018064760782756303,
#   ['goto',
#    "'Our Services'",
#    "'About Us'",
#    "'View Rates'",
#    "'Refinance'",
#    "'Custom'",
#    "near('Max Rate')",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'View Rates'",
#    "'Refinance'",
#    "'Custom'",
#    "near('Max Rate')"]],
#  [0.00016751894893508762,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Estimate a home\\'s cost')",
#    "near('3-6 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'"]],
#  [0.00015182402095718887,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Estimate a home\\'s cost')",
#    "near('6+ months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'About Us'",
#    "'View Rates'",
#    "'Refinance'",
#    "'Custom'",
#    "near('Max Rate')",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'"]],
#  [0.00010794502692411474,
#   ['goto',
#    "'Our Services'",
#    "'About Us'",
#    "'View Rates'",
#    "'Refinance'",
#    "'Custom'",
#    "near('Max Rate')",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    "near('Investment')",
#    "near('Townhouse or Condo')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    "near('Investment')",
#    "near('2 to 4 units')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')"]],
#  [0.00010386467046745583,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Find a real estate agent')",
#    "near('Not Sure')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'Refinance'",
#    "'Custom'",
#    "near('Max Rate')",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'"]],
#  [6.350892462687757e-05,
#   ['goto',
#    "'Our Services'",
#    "'About Us'",
#    "'View Rates'",
#    "'Refinance'",
#    "'Custom'",
#    "near('Max Rate')",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Find a real estate agent')",
#    "near('Not Sure')",
#    'citystatezip',
#    'CityNameWithZipCode']],
#  [6.231880228047351e-05,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('See how much I can afford')",
#    "near('6+ months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'Refinance'",
#    "'Custom'",
#    "near('Max Rate')",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'"]],
#  [3.264781438754175e-05,
#   ['goto',
#    "'Our Services'",
#    "'About Us'",
#    "'View Rates'",
#    "'Refinance'",
#    "'Custom'",
#    "near('Max Rate')",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Investment')",
#    "near('Townhouse or Condo')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    'email',
#    "'Continue'",
#    'Address',
#    "'Next'"]],
#  [3.089798946882407e-05,
#   ['goto',
#    "'Our Services'",
#    "'About Us'",
#    "'View Rates'",
#    "'Refinance'",
#    "'Custom'",
#    "near('Max Rate')",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Primary Residence')",
#    "near('Single Family')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'"]],
#  [2.2012636220581405e-05,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('See how much I can afford')",
#    "near('Not Sure')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'"]],
#  [2.1914621810846615e-05,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Get a Pre-approval Letter')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')"]],
#  [2.0710544439253178e-05,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('Or refinancing a home?')",
#    'location',
#    'Address',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Get a Pre-approval Letter')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')"]],
#  [1.9992489225654634e-05,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('See how much I can afford')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Not Sure')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'"]],
#  [1.8743877541166655e-05,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Find a real estate agent')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    "near('Investment')",
#    "near('Townhouse or Condo')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'"]],
#  [1.777486347072189e-05,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('Or refinancing a home?')",
#    'location',
#    'Address',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'"]],
#  [1.1006318110290702e-05,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('See how much I can afford')",
#    "near('Not Sure')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    'homeValue',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'"]],
#  [1.0582586023844446e-05,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Find a real estate agent')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'About Us'",
#    "'View Rates'",
#    "'Refinance'",
#    "'Custom'",
#    "near('Max Rate')",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address']],
#  [1.0253025854245074e-05,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('See how much I can afford')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Investment')",
#    "near('2 to 4 units')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Investment')",
#    "near('Townhouse or Condo')",
#    'monthlyRental',
#    'homeValue']],
#  [1.015574667793577e-05,
#   ['goto',
#    "'Our Services'",
#    "'About Us'",
#    "'View Rates'",
#    "'Refinance'",
#    "'Custom'",
#    "near('Max Rate')",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('I\\'m just researching')",
#    "near('Get a Pre-approval Letter')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Investment')",
#    "near('Townhouse or Condo')"]],
#  [9.262122028099612e-06,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m making offers')",
#    "near('Get a Pre-approval Letter')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Find a real estate agent')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'"]],
#  [9.21799145847491e-06,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Estimate a home\\'s cost')",
#    "near('3-6 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'View Rates'",
#    "'Refinance'",
#    "'Custom'",
#    "near('Max Rate')",
#    "near('20 Year')"]],
#  [8.804053727886539e-06,
#   ['goto',
#    "'Our Services'",
#    "'About Us'",
#    "'View Rates'",
#    "'Refinance'",
#    "'Custom'",
#    "near('Max Rate')",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('See how much I can afford')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('I\\'m making offers')",
#    "near('Get a Pre-approval Letter')",
#    "near('0–3 months')"]],
#  [8.629435933334454e-06,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Find a real estate agent')",
#    "near('Not Sure')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('I\\'m just researching')",
#    "near('Get a Pre-approval Letter')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'"]],
#  [7.5044139226655155e-06,
#   ['goto',
#    "'Our Services'",
#    "'About Us'",
#    "'View Rates'",
#    "'Refinance'",
#    "'Custom'",
#    "near('Max Rate')",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'",
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('I\\'m just researching')",
#    "near('Get a Pre-approval Letter')",
#    "near('0–3 months')"]],
#  [6.623651953712404e-06,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('See how much I can afford')",
#    "near('Not Sure')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Second Home')"]],
#  [6.505468549547054e-06,
#   ['goto',
#    "'Our Services'",
#    "'About Us'",
#    "'View Rates'",
#    "'Refinance'",
#    "'Custom'",
#    "near('Max Rate')",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('See how much I can afford')",
#    "near('6+ months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Investment')",
#    "near('Townhouse or Condo')"]],
#  [6.1731751805759305e-06,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Find a real estate agent')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Find a real estate agent')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'Our Services'",
#    "'About Us'",
#    "'View Rates'",
#    "'Refinance'",
#    "'Custom'",
#    "near('Max Rate')"]],
#  [5.3815577624663045e-06,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Estimate a home\\'s cost')",
#    "near('3-6 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    'goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m making offers')",
#    "near('Get a Pre-approval Letter')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email']],
#  [4.414640487643102e-06,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Estimate a home\\'s cost')",
#    "near('Not Sure')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Get a Pre-approval Letter')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'"]],
#  [3.978267247225442e-06,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('See how much I can afford')",
#    "near('Not Sure')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Second Home')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Investment')",
#    "near('Townhouse or Condo')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')"]],
#  [3.936273836021107e-06,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('See how much I can afford')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'Custom'",
#    "near('Max Rate')",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Primary Residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email']],
#  [3.795301957043109e-06,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('See how much I can afford')",
#    "near('Not Sure')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('I\\'m going to open houses')",
#    "near('See how much I can afford')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email']],
#  [3.7650440562368936e-06,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('See how much I can afford')",
#    "near('Not Sure')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Primary Residence')",
#    "near('Single Family')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'"]],
#  [3.388960001862723e-06,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('See how much I can afford')",
#    "near('6+ months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('3-6 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Investment')",
#    "near('Townhouse or Condo')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    'email']],
#  [3.3613840348392182e-06,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Estimate a home\\'s cost')",
#    "near('6+ months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Investment')",
#    "near('Townhouse or Condo')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    'homeValue',
#    "'Next'"]],
#  [3.192876906962531e-06,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Estimate a home\\'s cost')",
#    "near('3-6 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('I\\'m making offers')",
#    "near('Get a Pre-approval Letter')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'"]],
#  [2.8597985548882993e-06,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m making offers')",
#    "near('Get a Pre-approval Letter')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'See rates', near('Or refinancing a home?')",
#    'location',
#    'Address',
#    "'Next'",
#    'email']],
#  [2.6417972631924516e-06,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('See how much I can afford')",
#    "near('6+ months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Find a real estate agent')",
#    "near('Not Sure')",
#    'citystatezip',
#    'CityNameWithZipCode']],
#  [2.6265442474240906e-06,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('See how much I can afford')",
#    "near('Not Sure')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Investment')",
#    "near('2 to 4 units')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Investment')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')"]],
#  [2.453948204025076e-06,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('Or refinancing a home?')",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('6+ months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('2 Units')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'"]],
#  [2.3786291816929715e-06,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('Or refinancing a home?')",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Find a real estate agent')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email']],
#  [2.232452068445517e-06,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Estimate a home\\'s cost')",
#    "near('3-6 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('I\\'m going to open houses')",
#    "near('Estimate a home\\'s cost')",
#    "near('6+ months')",
#    'citystatezip']],
#  [2.1061056322641897e-06,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('Or refinancing a home?')",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Max Rate')",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'"]],
#  [2.03949143686874e-06,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('See how much I can afford')",
#    "near('6+ months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    'Address',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Investment')",
#    "near('Townhouse or Condo')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'"]],
#  [2.0279353246358815e-06,
#   ['goto',
#    "'Our Services'",
#    "'About Us'",
#    "'View Rates'",
#    "'Refinance'",
#    "'Custom'",
#    "near('Max Rate')",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Investment')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'Our Services'",
#    "'About Us'"]],
#  [2.0279353246358815e-06,
#   ['goto',
#    "'Our Services'",
#    "'About Us'",
#    "'View Rates'",
#    "'Refinance'",
#    "'Custom'",
#    "near('Max Rate')",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Investment')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'See rates', near('Or refinancing a home?')",
#    'location']],
#  [1.6588215857033266e-06,
#   ['goto',
#    "'Our Services'",
#    "'About Us'",
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Estimate a home\\'s cost')",
#    "near('3-6 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Investment')",
#    "near('Townhouse or Condo')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Townhouse or Condo')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    'email',
#    "'Continue'"]],
#  [1.5579700570118386e-06,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('See how much I can afford')",
#    "near('6+ months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('I\\'m just researching')",
#    "near('Get a Pre-approval Letter')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Primary Residence')",
#    "near('Single Family')"]],
#  [1.4738790375283868e-06,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('Or refinancing a home?')",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'Refinance'",
#    "'Custom'",
#    "near('Max Rate')",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    "near('Investment')",
#    "near('Townhouse or Condo')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'Get Started'"]],
#  [1.1376569658757368e-06,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('See how much I can afford')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Investment')",
#    "near('Townhouse or Condo')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    "near('Investment')",
#    "near('Single Family')"]],
#  [1.1239487667665072e-06,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('See how much I can afford')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Investment')",
#    "near('Townhouse or Condo')",
#    'monthlyRental']],
#  [9.911135492342697e-07,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Find a real estate agent')",
#    "near('Not Sure')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Townhouse or Condo')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    'homeValue',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')"]],
#  [9.641273385801018e-07,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Find a real estate agent')",
#    "near('Not Sure')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    "near('Primary Residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email']],
#  [8.476495606073309e-07,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m making offers')",
#    "near('Get a Pre-approval Letter')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Find a real estate agent')",
#    "near('6+ months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'"]],
#  [5.581971700385364e-07,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('See how much I can afford')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Investment')",
#    "near('Townhouse or Condo')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    "near('Primary Residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Investment')",
#    "near('Townhouse or Condo')",
#    'monthlyRental',
#    'homeValue']],
#  [5.375808139428868e-07,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Estimate a home\\'s cost')",
#    "near('Not Sure')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'See rates', near('Or refinancing a home?')",
#    'location',
#    'Address',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Find a real estate agent')",
#    "near('Not Sure')",
#    'citystatezip',
#    'CityNameWithZipCode']],
#  [5.257377094749161e-07,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Get a Pre-approval Letter')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Estimate a home\\'s cost')",
#    "near('Not Sure')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('3-6 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')"]],
#  [5.121236809956169e-07,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m just researching')",
#    "near('Get a Pre-approval Letter')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    "near('Investment')",
#    "near('2 to 4 units')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    'email',
#    "'Continue'"]],
#  [5.078903435893903e-07,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Find a real estate agent')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Investment')",
#    "near('2 to 4 units')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('3-6 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'Our Services'",
#    "'About Us'"]],
#  [4.6377871178369333e-07,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m making offers')",
#    "near('Get a Pre-approval Letter')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Get a Pre-approval Letter')",
#    "near('0–3 months')",
#    'citystatezip']],
#  [3.5804136996562263e-07,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m making offers')",
#    "near('Get a Pre-approval Letter')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Investment')",
#    "near('Townhouse or Condo')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('I\\'m making offers')",
#    "near('Get a Pre-approval Letter')",
#    "near('0–3 months')",
#    'citystatezip']],
#  [3.4726380266000736e-07,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Estimate a home\\'s cost')",
#    "near('3-6 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    'email',
#    "'Continue'",
#    "near('Townhouse or Condo')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    "near('Investment')",
#    "near('Townhouse or Condo')",
#    'monthlyRental',
#    'homeValue']],
#  [3.296143865517106e-07,
#   ['goto',
#    "'Our Services'",
#    "'About Us'",
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('See how much I can afford')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('6+ months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email']],
#  [3.2148385411663987e-07,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('See how much I can afford')",
#    "near('Not Sure')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Find a real estate agent')",
#    "near('Not Sure')"]],
#  [3.12572462587001e-07,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Estimate a home\\'s cost')",
#    "near('6+ months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Find a real estate agent')",
#    "near('Not Sure')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Investment')",
#    "near('Single Family')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'"]],
#  [3.079598111328939e-07,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Estimate a home\\'s cost')",
#    "near('6+ months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    'email',
#    "'Continue'",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('2 Units')",
#    'monthlyRental',
#    'homeValue']],
#  [2.9076308475138494e-07,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('Or refinancing a home?')",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('3-6 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Primary Residence')",
#    "near('Single Family')",
#    "'Next'"]],
#  [2.6727682595851923e-07,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Find a real estate agent')",
#    "near('Not Sure')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Second Home')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'"]],
#  [2.6473053510489613e-07,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Estimate a home\\'s cost')",
#    "near('Not Sure')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('3-6 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Investment')",
#    "near('Single Family')",
#    "'Next'",
#    'email']],
#  [2.2703094430255278e-07,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('Or refinancing a home?')",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'",
#    'email',
#    "'Continue'",
#    "near('2 to 4 units')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Max Rate')",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')"]],
#  [2.1034531697911297e-07,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Estimate a home\\'s cost')",
#    "near('6+ months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Investment')",
#    "near('Townhouse or Condo')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    "near('Investment')",
#    "near('Single Family')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Investment')",
#    "near('Townhouse or Condo')"]],
#  [2.0003505920744272e-07,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('Or refinancing a home?')",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'See rates', near('Or refinancing a home?')",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Find a real estate agent')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Investment')",
#    "near('Single Family')"]],
#  [1.5207950664974545e-07,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('See how much I can afford')",
#    "near('6+ months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Get a Pre-approval Letter')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('I\\'m going to open houses')",
#    "near('Find a real estate agent')",
#    "near('Not Sure')"]],
#  [1.4298992774441505e-07,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m making offers')",
#    "near('Get a Pre-approval Letter')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Investment')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'Continue'",
#    "'Refinance'",
#    "'Custom'",
#    "near('Max Rate')",
#    "near('20 Year')",
#    "'Get Started'",
#    'location']],
#  [1.1465963485495323e-07,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('See how much I can afford')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'Continue'",
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Max Rate')",
#    "near('20 Year')",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'"]],
#  [1.0779645324966148e-07,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('See how much I can afford')",
#    "near('Not Sure')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    'Address',
#    "'Next'",
#    "near('Investment')",
#    "near('2 to 4 units')",
#    'monthlyRental',
#    'homeValue']],
#  [1.0194125064398449e-07,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('Or refinancing a home?')",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('I\\'m just researching')",
#    "near('Get a Pre-approval Letter')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    'homeValue',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Get a Pre-approval Letter')"]],
#  [8.837140472261945e-08,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('Or refinancing a home?')",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('6+ months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Investment')",
#    "near('Townhouse or Condo')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('See how much I can afford')",
#    "near('6+ months')"]],
#  [8.826634476850394e-08,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Estimate a home\\'s cost')",
#    "near('Not Sure')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'About Us'",
#    "'See today\\'s rates'",
#    "'See rates', near('Or refinancing a home?')",
#    'location',
#    'Address',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('3-6 months')",
#    'citystatezip']],
#  [7.873007790758288e-08,
#   ['goto',
#    "'Our Services'",
#    "'About Us'",
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('See how much I can afford')",
#    "near('Not Sure')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('See how much I can afford')",
#    "near('6+ months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    'homeValue',
#    "'Next'",
#    'email',
#    "'Continue'"]],
#  [7.849715646600869e-08,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('See how much I can afford')",
#    "near('6+ months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Investment')",
#    "near('2 to 4 units')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    "near('Primary Residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email']],
#  [6.349827386575746e-08,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Estimate a home\\'s cost')",
#    "near('3-6 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Investment')",
#    "near('Townhouse or Condo')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    "near('Investment')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Investment')",
#    "near('Townhouse or Condo')",
#    'monthlyRental']],
#  [5.207481591859476e-08,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Estimate a home\\'s cost')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('2 to 4 units')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Investment')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'Next'"]],
#  [4.975964385764298e-08,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Find a real estate agent')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('I\\'m going to open houses')",
#    "near('Find a real estate agent')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    'email',
#    "'Continue'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'"]],
#  [2.3238665965193183e-08,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('Or refinancing a home?')",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Primary Residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Investment')",
#    "near('2 to 4 units')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    "near('Primary residence')"]],
#  [1.947462571264799e-08,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('See how much I can afford')",
#    "near('6+ months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'",
#    'homeValue',
#    "'Next'",
#    "near('Primary residence')"]],
#  [1.8502669436119435e-08,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('Or refinancing a home?')",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'Next'",
#    'email',
#    "'Continue'",
#    'goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Estimate a home\\'s cost')",
#    "near('6+ months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'See rates', near('Or refinancing a home?')",
#    'location']],
#  [1.2338333080521316e-08,
#   ['goto',
#    "'Our Services'",
#    "'About Us'",
#    "'See today\\'s rates'",
#    "'See rates', near('Or refinancing a home?')",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Find a real estate agent')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Second Home')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Investment')",
#    "near('Single Family')",
#    "'Next'",
#    "near('Primary residence')"]],
#  [1.2226119842729125e-08,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('Or refinancing a home?')",
#    'location',
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'Get Started'",
#    'location',
#    'Address',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    'email',
#    "'Continue'",
#    'Address',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Not Sure')"]],
#  [8.669113395693666e-09,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m going to open houses')",
#    "near('Find a real estate agent')",
#    "near('Not Sure')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    "'Next'",
#    'email',
#    "'Continue'",
#    'email',
#    "'Continue'",
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('3-6 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Investment')"]],
#  [2.9192357918363335e-09,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m making offers')",
#    "near('Get a Pre-approval Letter')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "'Next'",
#    'email',
#    "'Continue'",
#    'homeValue',
#    "'Next'",
#    "near('Investment')",
#    "near('2 to 4 units')",
#    'monthlyRental',
#    'homeValue',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('Get a Pre-approval Letter')"]],
#  [1.562324066931917e-09,
#   ['goto',
#    "'See today\\'s rates'",
#    "'See rates', near('First, are you buying?')",
#    "near('I\\'m making offers')",
#    "near('Get a Pre-approval Letter')",
#    "near('0–3 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Primary residence')",
#    "near('Single Family')",
#    'homeValue',
#    "'Next'",
#    'email',
#    "'Continue'",
#    "near('3-6 months')",
#    'citystatezip',
#    'CityNameWithZipCode',
#    "'Next'",
#    "near('Investment')",
#    "near('Single Family')",
#    'homeValue',
#    "'Next'",
#    "near('Investment')"]]]

# %%
#hmm = HiddenMarkovModel().from_samples(
#    NormalDistribution,n_components=5, X=sequences,end_state=True)
